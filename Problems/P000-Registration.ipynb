# %% [markdown]
# P000-Registration
# This is the problem required to register an account on projecteuler.net
#
# ![image.png](attachment:1cb4d987-5583-4396-b535-232724be1480.png)

# %%
import numpy as np

# %%
#the requested number changes per user currently 628,000
I = 628000

# %%
s = 0
i = 1
while i<=(I/2):
    s += (2*i-1)**2
    i += 1

# %%
print(s)
# Out:
# 41278858666562000
